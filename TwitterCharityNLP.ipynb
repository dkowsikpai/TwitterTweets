# %% [markdown]
# # Twitter Charity Related Text Extraction

# %% [markdown]
# ## Installing NLTK Library

# %%
# %pip install nltk pandas matplotlib

# %% [markdown]
# Import required Libraries and Loading data to pandas dataframe

# %%
import pandas as pd

# %%
amz = pd.read_csv("./Data/actforamazon.csv")
amz.head()
# Out:
#                 id_str       from_user  \
# 0  1235091941731098625      fabioruivo
# 1  1235071327775539200  jaimevargasnae
# 2  1234968672856428544  WaoResistencia
# 3  1234963918734417928      confeniae1
# 4  1234963918734417928      confeniae1
#
#                                                 text  \
# 0  .@CBF_Futebol @RedeGlobo @Ambev @CocaCola @ita...
# 1  RT @confeniae1: En las profundidades de la sel...
# 2  RT @confeniae1: En las profundidades de la sel...
# 3  En las profundidades de la selva amazónica hab...
# 4  En las profundidades de la selva amazónica hab...
#
#                        created_at                 time  geo_coordinates  \
# 0  Wed Mar 04 06:37:20 +0000 2020  04/03/2020 06:37:20              NaN
# 1  Wed Mar 04 05:15:25 +0000 2020  04/03/2020 05:15:25              NaN
# 2  Tue Mar 03 22:27:30 +0000 2020  03/03/2020 22:27:30              NaN
# 3  Tue Mar 03 22:08:37 +0000 2020  03/03/2020 22:08:37              NaN
# 4  Tue Mar 03 22:08:37 +0000 2020  03/03/2020 22:08:37              NaN
#
#    user_lang  in_reply_to_user_id_str in_reply_to_screen_name  \
# 0        NaN                      NaN                     NaN
# 1        NaN                      NaN                     NaN
# 2        NaN                      NaN                     NaN
# 3        NaN             1.321463e+09              confeniae1
# 4        NaN             1.321463e+09              confeniae1
#
#       from_user_id_str  in_reply_to_status_id_str  \
# 0             17015247                        NaN
# 1   890896112642646016                        NaN
# 2  1100052094365720576                        NaN
# 3           1321462820               1.234964e+18
# 4           1321462820               1.234964e+18
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="https://mobile.twitter.com" rel="nofo...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
#                                    profile_image_url  user_followers_count  \
# 0  http://pbs.twimg.com/profile_images/1164275859...                   793
# 1  http://pbs.twimg.com/profile_images/9135326966...                 37509
# 2  http://pbs.twimg.com/profile_images/1100056401...                  3237
# 3  http://pbs.twimg.com/profile_images/9964613968...                 33941
# 4  http://pbs.twimg.com/profile_images/9964613968...                 33941
#
#    user_friends_count             user_location  \
# 0                 282             Pale Blue Dot
# 1                 192  Morona Santiago, Ecuador
# 2                 865                       NaN
# 3                 991      Amazonía Ecuatoriana
# 4                 991      Amazonía Ecuatoriana
#
#                                           status_url  \
# 0  http://twitter.com/fabioruivo/statuses/1235091...
# 1  http://twitter.com/jaimevargasnae/statuses/123...
# 2  http://twitter.com/WaoResistencia/statuses/123...
# 3  http://twitter.com/confeniae1/statuses/1234963...
# 4  http://twitter.com/confeniae1/statuses/1234963...
#
#                                         entities_str
# 0  {"hashtags":[{"text":"WorldCup2014","indices":...
# 1  {"hashtags":[],"symbols":[],"user_mentions":[{...
# 2  {"hashtags":[],"symbols":[],"user_mentions":[{...
# 3  {"hashtags":[{"text":"AmazoníaSagrada","indice...
# 4  {"hashtags":[{"text":"AmazoníaSagrada","indice...

# %%
amz.shape
# Out:
# (5, 18)

# %%
amz.columns
# Out:
# Index(['id_str', 'from_user', 'text', 'created_at', 'time', 'geo_coordinates',
#        'user_lang', 'in_reply_to_user_id_str', 'in_reply_to_screen_name',
#        'from_user_id_str', 'in_reply_to_status_id_str', 'source',
#        'profile_image_url', 'user_followers_count', 'user_friends_count',
#        'user_location', 'status_url', 'entities_str'],
#       dtype='object')

# %%
amz.text[1]
# Out:
# 'RT @confeniae1: En las profundidades de la selva amazónica habita 1/3 de las especies que pueblan este planeta y se calcula que el 20% del agua potable disponible en el planeta se genera en este vasto ecosistema lleno de vida.\n\n#AmazoníaSagrada #SacredHeadwaters #KeepItUnderground \n#ActForAmazon https://t.co/SGahx3e1q5'

# %%
cmt = pd.read_csv("./Data/climatechange.csv")
cmt.head()
# Out:
#                 id_str        from_user  \
# 0  1235716715415105536     Australia_21
# 1  1235716674420006912  Shirley08391760
# 2  1235716603825672192    aileenwalsh16
# 3  1235716581264633856           RAAPTI
# 4  1235716553070366721      prollyhalal
#
#                                                 text  \
# 0  Have you thought about how we’ll meet the 21st...
# 1  RT @The_taX_Files: Not only did #ScottyFomMark...
# 2  RT @terraconcern: Professor Will Steffen gave ...
# 3  RT @zartajgulwazir: وزیر اعظم موسمیاتی تبدیلی ...
# 4  RT @majidahhashim: Thousands of #RedJellyfish ...
#
#                        created_at                 time geo_coordinates  \
# 0  Thu Mar 05 23:59:58 +0000 2020  05/03/2020 23:59:58             NaN
# 1  Thu Mar 05 23:59:48 +0000 2020  05/03/2020 23:59:48             NaN
# 2  Thu Mar 05 23:59:31 +0000 2020  05/03/2020 23:59:31             NaN
# 3  Thu Mar 05 23:59:26 +0000 2020  05/03/2020 23:59:26             NaN
# 4  Thu Mar 05 23:59:19 +0000 2020  05/03/2020 23:59:19             NaN
#
#    user_lang  in_reply_to_user_id_str in_reply_to_screen_name  \
# 0        NaN                      NaN                     NaN
# 1        NaN                      NaN                     NaN
# 2        NaN                      NaN                     NaN
# 3        NaN                      NaN                     NaN
# 4        NaN                      NaN                     NaN
#
#       from_user_id_str  in_reply_to_status_id_str  \
# 0            186716353                        NaN
# 1  1122054681180565505                        NaN
# 2           3024513774                        NaN
# 3   802303884995731456                        NaN
# 4            522793362                        NaN
#
#                                               source  \
# 0  <a href="https://buffer.com" rel="nofollow">Bu...
# 1  <a href="https://mobile.twitter.com" rel="nofo...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/android" ...
# 4  <a href="http://twitter.com/download/iphone" r...
#
#                                    profile_image_url  user_followers_count  \
# 0  http://pbs.twimg.com/profile_images/7631995434...                2612.0
# 1  http://pbs.twimg.com/profile_images/1134742705...                 261.0
# 2  http://pbs.twimg.com/profile_images/1206032443...                 732.0
# 3  http://pbs.twimg.com/profile_images/1237871731...                 753.0
# 4  http://pbs.twimg.com/profile_images/1140563800...                 539.0
#
#    user_friends_count               user_location  \
# 0              1959.0                    Canberra
# 1               256.0  Jindabyne, New South Wales
# 2              1650.0         Melbourne, Victoria
# 3              1264.0            Lahore, Pakistan
# 4               680.0                         NaN
#
#                                           status_url  \
# 0  http://twitter.com/Australia_21/statuses/12357...
# 1  http://twitter.com/Shirley08391760/statuses/12...
# 2  http://twitter.com/aileenwalsh16/statuses/1235...
# 3  http://twitter.com/RAAPTI/statuses/12357165812...
# 4  http://twitter.com/prollyhalal/statuses/123571...
#
#                                         entities_str
# 0  {"hashtags":[{"text":"ClimateChange","indices"...
# 1  {"hashtags":[{"text":"ScottyFomMarketing","ind...
# 2  {"hashtags":[{"text":"ClimateChange","indices"...
# 3  {"hashtags":[],"symbols":[],"user_mentions":[{...
# 4  {"hashtags":[{"text":"RedJellyfish","indices":...

# %%
cmt.columns
# Out:
# Index(['id_str', 'from_user', 'text', 'created_at', 'time', 'geo_coordinates',
#        'user_lang', 'in_reply_to_user_id_str', 'in_reply_to_screen_name',
#        'from_user_id_str', 'in_reply_to_status_id_str', 'source',
#        'profile_image_url', 'user_followers_count', 'user_friends_count',
#        'user_location', 'status_url', 'entities_str'],
#       dtype='object')

# %%
cmt.shape
# Out:
# (2975, 18)

# %%
cmt.entities_str[1]
# Out:
# '{"hashtags":[{"text":"ScottyFomMarketing","indices":[32,51]},{"text":"climateChange","indices":[82,96]},{"text":"AustralianFires","indices":[103,119]}],"symbols":[],"user_mentions":[{"screen_name":"The_taX_Files","name":"💧Fox Moulder 🔥","id":3013153314,"id_str":"3013153314","indices":[3,17]}],"urls":[]}'

# %%
cmt[cmt.text.str.contains("donation")].shape
# Out:
# (2, 18)

# %%
fire = pd.read_csv("./Data/forestfie.csv")
fire.head()
# Out:
#                 id_str        from_user  \
# 0  1235716715415105536     Australia_21
# 1  1235716674420006912  Shirley08391760
# 2  1235716603825672192    aileenwalsh16
# 3  1235716581264633856           RAAPTI
# 4  1235716553070366721      prollyhalal
#
#                                                 text  \
# 0  Have you thought about how we’ll meet the 21st...
# 1  RT @The_taX_Files: Not only did #ScottyFomMark...
# 2  RT @terraconcern: Professor Will Steffen gave ...
# 3  RT @zartajgulwazir: وزیر اعظم موسمیاتی تبدیلی ...
# 4  RT @majidahhashim: Thousands of #RedJellyfish ...
#
#                        created_at                 time geo_coordinates  \
# 0  Thu Mar 05 23:59:58 +0000 2020  05/03/2020 23:59:58             NaN
# 1  Thu Mar 05 23:59:48 +0000 2020  05/03/2020 23:59:48             NaN
# 2  Thu Mar 05 23:59:31 +0000 2020  05/03/2020 23:59:31             NaN
# 3  Thu Mar 05 23:59:26 +0000 2020  05/03/2020 23:59:26             NaN
# 4  Thu Mar 05 23:59:19 +0000 2020  05/03/2020 23:59:19             NaN
#
#    user_lang  in_reply_to_user_id_str in_reply_to_screen_name  \
# 0        NaN                      NaN                     NaN
# 1        NaN                      NaN                     NaN
# 2        NaN                      NaN                     NaN
# 3        NaN                      NaN                     NaN
# 4        NaN                      NaN                     NaN
#
#       from_user_id_str  in_reply_to_status_id_str  \
# 0            186716353                        NaN
# 1  1122054681180565505                        NaN
# 2           3024513774                        NaN
# 3   802303884995731456                        NaN
# 4            522793362                        NaN
#
#                                               source  \
# 0  <a href="https://buffer.com" rel="nofollow">Bu...
# 1  <a href="https://mobile.twitter.com" rel="nofo...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/android" ...
# 4  <a href="http://twitter.com/download/iphone" r...
#
#                                    profile_image_url  user_followers_count  \
# 0  http://pbs.twimg.com/profile_images/7631995434...                2612.0
# 1  http://pbs.twimg.com/profile_images/1134742705...                 261.0
# 2  http://pbs.twimg.com/profile_images/1206032443...                 732.0
# 3  http://pbs.twimg.com/profile_images/1237871731...                 753.0
# 4  http://pbs.twimg.com/profile_images/1140563800...                 539.0
#
#    user_friends_count               user_location  \
# 0              1959.0                    Canberra
# 1               256.0  Jindabyne, New South Wales
# 2              1650.0         Melbourne, Victoria
# 3              1264.0            Lahore, Pakistan
# 4               680.0                         NaN
#
#                                           status_url  \
# 0  http://twitter.com/Australia_21/statuses/12357...
# 1  http://twitter.com/Shirley08391760/statuses/12...
# 2  http://twitter.com/aileenwalsh16/statuses/1235...
# 3  http://twitter.com/RAAPTI/statuses/12357165812...
# 4  http://twitter.com/prollyhalal/statuses/123571...
#
#                                         entities_str
# 0  {"hashtags":[{"text":"ClimateChange","indices"...
# 1  {"hashtags":[{"text":"ScottyFomMarketing","ind...
# 2  {"hashtags":[{"text":"ClimateChange","indices"...
# 3  {"hashtags":[],"symbols":[],"user_mentions":[{...
# 4  {"hashtags":[{"text":"RedJellyfish","indices":...

# %%
fire.shape[0]
# Out:
# 2975

# %%
fire.columns
# Out:
# Index(['id_str', 'from_user', 'text', 'created_at', 'time', 'geo_coordinates',
#        'user_lang', 'in_reply_to_user_id_str', 'in_reply_to_screen_name',
#        'from_user_id_str', 'in_reply_to_status_id_str', 'source',
#        'profile_image_url', 'user_followers_count', 'user_friends_count',
#        'user_location', 'status_url', 'entities_str'],
#       dtype='object')

# %% [markdown]
# ### Checking count before stemming and removing stopping words
#
# Modify `keyword` variable to add or remove keywords

# %%
keyword_df = pd.read_csv("./Data/charity-keyword.csv")
keyword_df.head()
# Out:
#   communities
# 0    disaster
# 1     dollars
# 2    donation
# 3   donations
# 4   Emergency

# %%
keywords = keyword_df.communities.to_list()
print(keywords)
# Out:
# ['disaster', 'dollars', 'donation', 'donations', 'Emergency', 'families', 'families,', 'Foundation', 'Fund', 'help', 'impacted', 'initiatives', 'needs of', 'purpose', 'Relief', 'seeking', 'shelter', 'Support', 'transfer', 'urge', 'volunteers', 'website']

# %% [markdown]
# Counting rows that contain the keywords

# %%
key_dictionary = dict()
for i in keywords:
    key_dictionary[i] = key_dictionary.get(i, 0) + cmt[cmt.text.str.contains(i)].shape[0] + fire[fire.text.str.contains(i)].shape[0] + amz[amz.text.str.contains(i)].shape[0] 
print(key_dictionary)
# Out:
# {'disaster': 30, 'dollars': 4, 'donation': 4, 'donations': 4, 'Emergency': 508, 'families': 14, 'families,': 0, 'Foundation': 2, 'Fund': 18, 'help': 212, 'impacted': 2, 'initiatives': 0, 'needs of': 4, 'purpose': 4, 'Relief': 0, 'seeking': 12, 'shelter': 2, 'Support': 6, 'transfer': 4, 'urge': 90, 'volunteers': 2, 'website': 2}

# %% [markdown]
# ### Importing Plotting Library

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
Y = []
for  i in keywords:
    Y.append(key_dictionary[i])
plt.figure(figsize=(8, 9))
plt.bar(keywords, Y)
plt.title("Keywords count in Corpora")
plt.ylabel("Count")
plt.xlabel("Key Words")
plt.xticks(rotation=45) # Rotate the xlabel to 45 degree
plt.show()

# %% [markdown]
# ## Using NLTK for extraction

# %%
import nltk
from nltk.stem import WordNetLemmatizer # If we want to lemmatize the words. (Not used in this notebook)
from nltk.tokenize import TweetTokenizer # TweetTokenizer  (Not used in this notebook)
from nltk.tokenize import word_tokenize # Word Tokenization
from nltk.stem import PorterStemmer # Stemming the words to root part of the word
from nltk.corpus import stopwords # Premoving the stopping words

# %% [markdown]
# ### If you are running for the first time uncomment the following cell and download then comment after successful execution
# (98 MB)

# %%
nltk.download('wordnet')
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package wordnet to /home/hp/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /home/hp/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/hp/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# Setting the Stop words to English (Check Documentation for other languages)

# %%
stop_words = set(stopwords.words('english'))

# %% [markdown]
# ## Testing before applying to whole dataset
#
# Word Tokenization

# %%
text = fire.text[0]
tokens = word_tokenize(text)
print(tokens)
# Out:
# ['Have', 'you', 'thought', 'about', 'how', 'we', '’', 'll', 'meet', 'the', '21st', 'Century', 'challenges', 'of', 'climate', 'change', ',', 'plus', 'food', ',', 'water', 'and', 'energy', 'security', '?', 'Australia', 'needs', 'to', 'look', 'at', 'its', 'landscapes', 'in', 'new', 'ways', ':', 'https', ':', '//t.co/WiUZsDSh2S', '#', 'ClimateChange', '#', 'Sustainability', 'https', ':', '//t.co/jnvhN1cu6r']

# %% [markdown]
# Stemming

# %%
st_list = []
ps = PorterStemmer()
for w in tokens: 
    st = ps.stem(w)
    st_list.append(st)
print(st_list)
# Out:
# ['have', 'you', 'thought', 'about', 'how', 'we', '’', 'll', 'meet', 'the', '21st', 'centuri', 'challeng', 'of', 'climat', 'chang', ',', 'plu', 'food', ',', 'water', 'and', 'energi', 'secur', '?', 'australia', 'need', 'to', 'look', 'at', 'it', 'landscap', 'in', 'new', 'way', ':', 'http', ':', '//t.co/wiuzsdsh2', '#', 'climatechang', '#', 'sustain', 'http', ':', '//t.co/jnvhn1cu6r']

# %% [markdown]
# Removing Stopping words

# %%
filtered_sentence = [w for w in st_list if not w in stop_words] 
print(filtered_sentence)
# Out:
# ['thought', '’', 'meet', '21st', 'centuri', 'challeng', 'climat', 'chang', ',', 'plu', 'food', ',', 'water', 'energi', 'secur', '?', 'australia', 'need', 'look', 'landscap', 'new', 'way', ':', 'http', ':', '//t.co/wiuzsdsh2', '#', 'climatechang', '#', 'sustain', 'http', ':', '//t.co/jnvhn1cu6r']

# %% [markdown]
# ## Applying to Dataset
#
# Following are the functions for tokenisation, stemming and removing stopping words

# %%
def tokenize_txt(text):
    return word_tokenize(text)

# %%
def stem_txt(tokens):
    st_list = []
    ps = PorterStemmer() 
    for w in tokens: 
        st_list.append(ps.stem(w))
    return st_list

# %%
def rm_stop_words(token):
    return [w for w in token if not w in stop_words]

# %% [markdown]
# #### Stemming th keywords to match stemmed list

# %%
stemed_keywords = stem_txt(keywords)

# %% [markdown]
# #### Combination of above function to apply on the dataset

# %%
def filter_text(text):
    return rm_stop_words(stem_txt(tokenize_txt(text)))

# %%
cmt["filter_text"] = cmt["text"].apply(filter_text)
cmt.head()
# Out:
#                 id_str        from_user  \
# 0  1235716715415105536     Australia_21
# 1  1235716674420006912  Shirley08391760
# 2  1235716603825672192    aileenwalsh16
# 3  1235716581264633856           RAAPTI
# 4  1235716553070366721      prollyhalal
#
#                                                 text  \
# 0  Have you thought about how we’ll meet the 21st...
# 1  RT @The_taX_Files: Not only did #ScottyFomMark...
# 2  RT @terraconcern: Professor Will Steffen gave ...
# 3  RT @zartajgulwazir: وزیر اعظم موسمیاتی تبدیلی ...
# 4  RT @majidahhashim: Thousands of #RedJellyfish ...
#
#                        created_at                 time geo_coordinates  \
# 0  Thu Mar 05 23:59:58 +0000 2020  05/03/2020 23:59:58             NaN
# 1  Thu Mar 05 23:59:48 +0000 2020  05/03/2020 23:59:48             NaN
# 2  Thu Mar 05 23:59:31 +0000 2020  05/03/2020 23:59:31             NaN
# 3  Thu Mar 05 23:59:26 +0000 2020  05/03/2020 23:59:26             NaN
# 4  Thu Mar 05 23:59:19 +0000 2020  05/03/2020 23:59:19             NaN
#
#    user_lang  in_reply_to_user_id_str in_reply_to_screen_name  \
# 0        NaN                      NaN                     NaN
# 1        NaN                      NaN                     NaN
# 2        NaN                      NaN                     NaN
# 3        NaN                      NaN                     NaN
# 4        NaN                      NaN                     NaN
#
#       from_user_id_str  in_reply_to_status_id_str  \
# 0            186716353                        NaN
# 1  1122054681180565505                        NaN
# 2           3024513774                        NaN
# 3   802303884995731456                        NaN
# 4            522793362                        NaN
#
#                                               source  \
# 0  <a href="https://buffer.com" rel="nofollow">Bu...
# 1  <a href="https://mobile.twitter.com" rel="nofo...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/android" ...
# 4  <a href="http://twitter.com/download/iphone" r...
#
#                                    profile_image_url  user_followers_count  \
# 0  http://pbs.twimg.com/profile_images/7631995434...                2612.0
# 1  http://pbs.twimg.com/profile_images/1134742705...                 261.0
# 2  http://pbs.twimg.com/profile_images/1206032443...                 732.0
# 3  http://pbs.twimg.com/profile_images/1237871731...                 753.0
# 4  http://pbs.twimg.com/profile_images/1140563800...                 539.0
#
#    user_friends_count               user_location  \
# 0              1959.0                    Canberra
# 1               256.0  Jindabyne, New South Wales
# 2              1650.0         Melbourne, Victoria
# 3              1264.0            Lahore, Pakistan
# 4               680.0                         NaN
#
#                                           status_url  \
# 0  http://twitter.com/Australia_21/statuses/12357...
# 1  http://twitter.com/Shirley08391760/statuses/12...
# 2  http://twitter.com/aileenwalsh16/statuses/1235...
# 3  http://twitter.com/RAAPTI/statuses/12357165812...
# 4  http://twitter.com/prollyhalal/statuses/123571...
#
#                                         entities_str  \
# 0  {"hashtags":[{"text":"ClimateChange","indices"...
# 1  {"hashtags":[{"text":"ScottyFomMarketing","ind...
# 2  {"hashtags":[{"text":"ClimateChange","indices"...
# 3  {"hashtags":[],"symbols":[],"user_mentions":[{...
# 4  {"hashtags":[{"text":"RedJellyfish","indices":...
#
#                                          filter_text
# 0  [thought, ’, meet, 21st, centuri, challeng, cl...
# 1  [RT, @, the_tax_fil, :, onli, #, scottyfommark...
# 2  [RT, @, terraconcern, :, professor, steffen, g...
# 3  [RT, @, zartajgulwazir, :, وزیر, اعظم, موسمیات...
# 4  [RT, @, majidahhashim, :, thousand, #, redjell...

# %%
fire["filter_text"] = fire["text"].apply(filter_text)
fire.head()
# Out:
#                 id_str        from_user  \
# 0  1235716715415105536     Australia_21
# 1  1235716674420006912  Shirley08391760
# 2  1235716603825672192    aileenwalsh16
# 3  1235716581264633856           RAAPTI
# 4  1235716553070366721      prollyhalal
#
#                                                 text  \
# 0  Have you thought about how we’ll meet the 21st...
# 1  RT @The_taX_Files: Not only did #ScottyFomMark...
# 2  RT @terraconcern: Professor Will Steffen gave ...
# 3  RT @zartajgulwazir: وزیر اعظم موسمیاتی تبدیلی ...
# 4  RT @majidahhashim: Thousands of #RedJellyfish ...
#
#                        created_at                 time geo_coordinates  \
# 0  Thu Mar 05 23:59:58 +0000 2020  05/03/2020 23:59:58             NaN
# 1  Thu Mar 05 23:59:48 +0000 2020  05/03/2020 23:59:48             NaN
# 2  Thu Mar 05 23:59:31 +0000 2020  05/03/2020 23:59:31             NaN
# 3  Thu Mar 05 23:59:26 +0000 2020  05/03/2020 23:59:26             NaN
# 4  Thu Mar 05 23:59:19 +0000 2020  05/03/2020 23:59:19             NaN
#
#    user_lang  in_reply_to_user_id_str in_reply_to_screen_name  \
# 0        NaN                      NaN                     NaN
# 1        NaN                      NaN                     NaN
# 2        NaN                      NaN                     NaN
# 3        NaN                      NaN                     NaN
# 4        NaN                      NaN                     NaN
#
#       from_user_id_str  in_reply_to_status_id_str  \
# 0            186716353                        NaN
# 1  1122054681180565505                        NaN
# 2           3024513774                        NaN
# 3   802303884995731456                        NaN
# 4            522793362                        NaN
#
#                                               source  \
# 0  <a href="https://buffer.com" rel="nofollow">Bu...
# 1  <a href="https://mobile.twitter.com" rel="nofo...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/android" ...
# 4  <a href="http://twitter.com/download/iphone" r...
#
#                                    profile_image_url  user_followers_count  \
# 0  http://pbs.twimg.com/profile_images/7631995434...                2612.0
# 1  http://pbs.twimg.com/profile_images/1134742705...                 261.0
# 2  http://pbs.twimg.com/profile_images/1206032443...                 732.0
# 3  http://pbs.twimg.com/profile_images/1237871731...                 753.0
# 4  http://pbs.twimg.com/profile_images/1140563800...                 539.0
#
#    user_friends_count               user_location  \
# 0              1959.0                    Canberra
# 1               256.0  Jindabyne, New South Wales
# 2              1650.0         Melbourne, Victoria
# 3              1264.0            Lahore, Pakistan
# 4               680.0                         NaN
#
#                                           status_url  \
# 0  http://twitter.com/Australia_21/statuses/12357...
# 1  http://twitter.com/Shirley08391760/statuses/12...
# 2  http://twitter.com/aileenwalsh16/statuses/1235...
# 3  http://twitter.com/RAAPTI/statuses/12357165812...
# 4  http://twitter.com/prollyhalal/statuses/123571...
#
#                                         entities_str  \
# 0  {"hashtags":[{"text":"ClimateChange","indices"...
# 1  {"hashtags":[{"text":"ScottyFomMarketing","ind...
# 2  {"hashtags":[{"text":"ClimateChange","indices"...
# 3  {"hashtags":[],"symbols":[],"user_mentions":[{...
# 4  {"hashtags":[{"text":"RedJellyfish","indices":...
#
#                                          filter_text
# 0  [thought, ’, meet, 21st, centuri, challeng, cl...
# 1  [RT, @, the_tax_fil, :, onli, #, scottyfommark...
# 2  [RT, @, terraconcern, :, professor, steffen, g...
# 3  [RT, @, zartajgulwazir, :, وزیر, اعظم, موسمیات...
# 4  [RT, @, majidahhashim, :, thousand, #, redjell...

# %%
amz["filter_text"] = amz["text"].apply(filter_text)
amz.head()
# Out:
#                 id_str       from_user  \
# 0  1235091941731098625      fabioruivo
# 1  1235071327775539200  jaimevargasnae
# 2  1234968672856428544  WaoResistencia
# 3  1234963918734417928      confeniae1
# 4  1234963918734417928      confeniae1
#
#                                                 text  \
# 0  .@CBF_Futebol @RedeGlobo @Ambev @CocaCola @ita...
# 1  RT @confeniae1: En las profundidades de la sel...
# 2  RT @confeniae1: En las profundidades de la sel...
# 3  En las profundidades de la selva amazónica hab...
# 4  En las profundidades de la selva amazónica hab...
#
#                        created_at                 time  geo_coordinates  \
# 0  Wed Mar 04 06:37:20 +0000 2020  04/03/2020 06:37:20              NaN
# 1  Wed Mar 04 05:15:25 +0000 2020  04/03/2020 05:15:25              NaN
# 2  Tue Mar 03 22:27:30 +0000 2020  03/03/2020 22:27:30              NaN
# 3  Tue Mar 03 22:08:37 +0000 2020  03/03/2020 22:08:37              NaN
# 4  Tue Mar 03 22:08:37 +0000 2020  03/03/2020 22:08:37              NaN
#
#    user_lang  in_reply_to_user_id_str in_reply_to_screen_name  \
# 0        NaN                      NaN                     NaN
# 1        NaN                      NaN                     NaN
# 2        NaN                      NaN                     NaN
# 3        NaN             1.321463e+09              confeniae1
# 4        NaN             1.321463e+09              confeniae1
#
#       from_user_id_str  in_reply_to_status_id_str  \
# 0             17015247                        NaN
# 1   890896112642646016                        NaN
# 2  1100052094365720576                        NaN
# 3           1321462820               1.234964e+18
# 4           1321462820               1.234964e+18
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="https://mobile.twitter.com" rel="nofo...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
#                                    profile_image_url  user_followers_count  \
# 0  http://pbs.twimg.com/profile_images/1164275859...                   793
# 1  http://pbs.twimg.com/profile_images/9135326966...                 37509
# 2  http://pbs.twimg.com/profile_images/1100056401...                  3237
# 3  http://pbs.twimg.com/profile_images/9964613968...                 33941
# 4  http://pbs.twimg.com/profile_images/9964613968...                 33941
#
#    user_friends_count             user_location  \
# 0                 282             Pale Blue Dot
# 1                 192  Morona Santiago, Ecuador
# 2                 865                       NaN
# 3                 991      Amazonía Ecuatoriana
# 4                 991      Amazonía Ecuatoriana
#
#                                           status_url  \
# 0  http://twitter.com/fabioruivo/statuses/1235091...
# 1  http://twitter.com/jaimevargasnae/statuses/123...
# 2  http://twitter.com/WaoResistencia/statuses/123...
# 3  http://twitter.com/confeniae1/statuses/1234963...
# 4  http://twitter.com/confeniae1/statuses/1234963...
#
#                                         entities_str  \
# 0  {"hashtags":[{"text":"WorldCup2014","indices":...
# 1  {"hashtags":[],"symbols":[],"user_mentions":[{...
# 2  {"hashtags":[],"symbols":[],"user_mentions":[{...
# 3  {"hashtags":[{"text":"AmazoníaSagrada","indice...
# 4  {"hashtags":[{"text":"AmazoníaSagrada","indice...
#
#                                          filter_text
# 0  [., @, cbf_futebol, @, redeglobo, @, ambev, @,...
# 1  [RT, @, confeniae1, :, En, la, profundidad, de...
# 2  [RT, @, confeniae1, :, En, la, profundidad, de...
# 3  [En, la, profundidad, de, la, selva, amazónica...
# 4  [En, la, profundidad, de, la, selva, amazónica...

# %% [markdown]
# ## Counting again.

# %%
key_dictionary = dict()
requrired_dataset = pd.DataFrame()
for i in stemed_keywords:
    cmt_filtered = cmt[cmt.filter_text.apply(lambda x: i in x)]
    fire_filtered = fire[fire.filter_text.apply(lambda x: i in x)]
    amz_filtered = amz[amz.filter_text.apply(lambda x: i in x)]
    requrired_dataset = pd.concat([requrired_dataset, cmt_filtered, fire_filtered, amz_filtered], axis="rows")
    key_dictionary[i] = key_dictionary.get(i, 0) + cmt_filtered.shape[0] + fire_filtered.shape[0] + amz_filtered.shape[0]  
print(key_dictionary)
# Out:
# {'disast': 32, 'dollar': 8, 'donat': 44, 'emerg': 62, 'famili': 28, 'families,': 0, 'foundat': 6, 'fund': 62, 'help': 178, 'impact': 178, 'initi': 8, 'needs of': 0, 'purpos': 6, 'relief': 12, 'seek': 14, 'shelter': 2, 'support': 186, 'transfer': 4, 'urg': 2, 'volunt': 2, 'websit': 2}

# %%
Y = []
for  i in range(len(keywords)):
    Y.append(key_dictionary[stemed_keywords[i]])
plt.figure(figsize=(8, 9))
plt.bar(keywords, Y)
plt.title("Keywords count in Corpora. After Stemming and Filtering")
plt.ylabel("Count")
plt.xlabel("Key Words")
plt.xticks(rotation=45) # Rotate xlabel to 45 degree
plt.show()

# %% [markdown]
# ### Checking the Required Dataset
#
# Reseting Index because after concatination it will be index of those rows which are appended. So we need to reset it to have unique numbering from index 0

# %%
requrired_dataset.reset_index(inplace=True)

# %%
requrired_dataset.shape
# Out:
# (836, 20)

# %% [markdown]
# #### Evaluvating the output.
#
# Here is an example of output _(Indexed at 1. Index Starts from 0. Ends at the 28)_

# %%
requrired_dataset.text[1]
# Out:
# 'Just imagine a couple of these viruses occurring during a climate worsened disaster. It will bring the global economy to its knees and there will be literally nothing we could do about it. Time for action is now. #ClimateChange #cdnpoli https://t.co/vCNa7Cd4oB'

# %% [markdown]
# ### Printing first 10 text that are having the keywords

# %%
requrired_dataset.head(10) # Count Starting from zero
# Out:
#    index               id_str       from_user  \
# 0     60  1235714622671503361       LABruce14
# 1     84  1235714035682664449     impishchimp
# 2     98  1235713508651814912     Euthyphraud
# 3    318  1235706520207339523     TujyeKunywa
# 4    367  1235705264688336896  carycharlesart
# 5    388  1235704592601497600     profjmcadam
# 6    408  1235703943138652160      Vfloribert
# 7    410  1235703855813480451  imagine_garden
# 8    438  1235703226466316288       Stop2Care
# 9    528  1235700784190255104           gdgoz
#
#                                                 text  \
# 0  Wonder how @algore @AOC @GretaThunberg &amp; t...
# 1  Just imagine a couple of these viruses occurri...
# 2  @GravelInstitute @realDonaldTrump supports (PR...
# 3  RT @Vfloribert: Awareness for #SafetyFirst #Sa...
# 4  RT @Stop2Care: Why aren't more "news" people s...
# 5  New pact paves way for innovative solutions to...
# 6  Awareness for #SafetyFirst #Safetyispersonal b...
# 7  RT @Stop2Care: Why aren't more "news" people s...
# 8  Why aren't more "news" people saying that the ...
# 9  RT @TAFEeducation: ‘Two research papers releas...
#
#                        created_at                 time geo_coordinates  \
# 0  Thu Mar 05 23:51:39 +0000 2020  05/03/2020 23:51:39             NaN
# 1  Thu Mar 05 23:49:19 +0000 2020  05/03/2020 23:49:19             NaN
# 2  Thu Mar 05 23:47:13 +0000 2020  05/03/2020 23:47:13             NaN
# 3  Thu Mar 05 23:19:27 +0000 2020  05/03/2020 23:19:27             NaN
# 4  Thu Mar 05 23:14:28 +0000 2020  05/03/2020 23:14:28             NaN
# 5  Thu Mar 05 23:11:47 +0000 2020  05/03/2020 23:11:47             NaN
# 6  Thu Mar 05 23:09:12 +0000 2020  05/03/2020 23:09:12             NaN
# 7  Thu Mar 05 23:08:52 +0000 2020  05/03/2020 23:08:52             NaN
# 8  Thu Mar 05 23:06:22 +0000 2020  05/03/2020 23:06:22             NaN
# 9  Thu Mar 05 22:56:39 +0000 2020  05/03/2020 22:56:39             NaN
#
#    user_lang  in_reply_to_user_id_str in_reply_to_screen_name  \
# 0        NaN                      NaN                     NaN
# 1        NaN                      NaN                     NaN
# 2        NaN               14709326.0         GravelInstitute
# 3        NaN                      NaN                     NaN
# 4        NaN                      NaN                     NaN
# 5        NaN                      NaN                     NaN
# 6        NaN                      NaN                     NaN
# 7        NaN                      NaN                     NaN
# 8        NaN                      NaN                     NaN
# 9        NaN                      NaN                     NaN
#
#       from_user_id_str  in_reply_to_status_id_str  \
# 0  1175516433469595648                        NaN
# 1            193566462                        NaN
# 2   936038790346493952               1.235394e+18
# 3           4820930547                        NaN
# 4            620222951                        NaN
# 5           2655609206                        NaN
# 6            882641197                        NaN
# 7            141009810                        NaN
# 8            100701580                        NaN
# 9            252420272                        NaN
#
#                                               source  \
# 0  <a href="https://mobile.twitter.com" rel="nofo...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="https://mobile.twitter.com" rel="nofo...
# 3  <a href="http://www.twitter.com" rel="nofollow...
# 4  <a href="http://twitter.com/download/android" ...
# 5  <a href="https://mobile.twitter.com" rel="nofo...
# 6  <a href="http://twitter.com/download/android" ...
# 7  <a href="http://discussionexpress.com" rel="no...
# 8  <a href="https://mobile.twitter.com" rel="nofo...
# 9  <a href="http://twitter.com/#!/download/ipad" ...
#
#                                    profile_image_url  user_followers_count  \
# 0  http://pbs.twimg.com/profile_images/1213625794...                  51.0
# 1  http://pbs.twimg.com/profile_images/9927964040...                2572.0
# 2  http://pbs.twimg.com/profile_images/1200850612...                  19.0
# 3  http://pbs.twimg.com/profile_images/1178201475...                2026.0
# 4  http://pbs.twimg.com/profile_images/1191861187...                 127.0
# 5  http://pbs.twimg.com/profile_images/4899826396...                5979.0
# 6  http://pbs.twimg.com/profile_images/1054953970...                  78.0
# 7  http://pbs.twimg.com/profile_images/9793274298...                3034.0
# 8  http://pbs.twimg.com/profile_images/4938252281...                 215.0
# 9  http://pbs.twimg.com/profile_images/3685777612...                2646.0
#
#    user_friends_count                   user_location  \
# 0               403.0  Texas United States of America
# 1               288.0                       BC Canada
# 2               396.0                         Indiana
# 3                 2.0                          Rwanda
# 4               432.0       South Island, New Zealand
# 5              1187.0                             NaN
# 6               167.0                          Global
# 7               830.0                              NJ
# 8               710.0                 Marin County CA
# 9              4982.0                       Australia
#
#                                           status_url  \
# 0  http://twitter.com/LABruce14/statuses/12357146...
# 1  http://twitter.com/impishchimp/statuses/123571...
# 2  http://twitter.com/Euthyphraud/statuses/123571...
# 3  http://twitter.com/TujyeKunywa/statuses/123570...
# 4  http://twitter.com/carycharlesart/statuses/123...
# 5  http://twitter.com/profjmcadam/statuses/123570...
# 6  http://twitter.com/Vfloribert/statuses/1235703...
# 7  http://twitter.com/imagine_garden/statuses/123...
# 8  http://twitter.com/Stop2Care/statuses/12357032...
# 9  http://twitter.com/gdgoz/statuses/123570078419...
#
#                                         entities_str  \
# 0  {"hashtags":[{"text":"ClimateChange","indices"...
# 1  {"hashtags":[{"text":"ClimateChange","indices"...
# 2  {"hashtags":[{"text":"China","indices":[90,96]...
# 3  {"hashtags":[{"text":"SafetyFirst","indices":[...
# 4  {"hashtags":[{"text":"healthcare","indices":[6...
# 5  {"hashtags":[{"text":"disaster","indices":[47,...
# 6  {"hashtags":[{"text":"SafetyFirst","indices":[...
# 7  {"hashtags":[{"text":"healthcare","indices":[6...
# 8  {"hashtags":[{"text":"healthcare","indices":[5...
# 9  {"hashtags":[],"symbols":[],"user_mentions":[{...
#
#                                          filter_text
# 0  [wonder, @, algor, @, aoc, @, gretathunberg, &...
# 1  [imagin, coupl, virus, occur, dure, climat, wo...
# 2  [@, gravelinstitut, @, realdonaldtrump, suppor...
# 3  [RT, @, vfloribert, :, awar, #, safetyfirst, #...
# 4  [RT, @, stop2car, :, whi, n't, ``, news, '', p...
# 5  [new, pact, pave, way, innov, solut, #, disast...
# 6  [awar, #, safetyfirst, #, safetyisperson, base...
# 7  [RT, @, stop2car, :, whi, n't, ``, news, '', p...
# 8  [whi, n't, ``, news, '', peopl, say, reason, #...
# 9  [RT, @, tafeeduc, :, ‘, two, research, paper, ...

# %% [markdown]
# ## Writing to a CSV file

# %%
requrired_dataset.to_csv("./Data/result.csv")

# %% [markdown]
# ## Reading Back from file.

# %%
df = pd.read_csv("./Data/result.csv")
df.head(10)
# Out:
#    Unnamed: 0  index               id_str       from_user  \
# 0           0     60  1235714622671503361       LABruce14
# 1           1     84  1235714035682664449     impishchimp
# 2           2     98  1235713508651814912     Euthyphraud
# 3           3    318  1235706520207339523     TujyeKunywa
# 4           4    367  1235705264688336896  carycharlesart
# 5           5    388  1235704592601497600     profjmcadam
# 6           6    408  1235703943138652160      Vfloribert
# 7           7    410  1235703855813480451  imagine_garden
# 8           8    438  1235703226466316288       Stop2Care
# 9           9    528  1235700784190255104           gdgoz
#
#                                                 text  \
# 0  Wonder how @algore @AOC @GretaThunberg &amp; t...
# 1  Just imagine a couple of these viruses occurri...
# 2  @GravelInstitute @realDonaldTrump supports (PR...
# 3  RT @Vfloribert: Awareness for #SafetyFirst #Sa...
# 4  RT @Stop2Care: Why aren't more "news" people s...
# 5  New pact paves way for innovative solutions to...
# 6  Awareness for #SafetyFirst #Safetyispersonal b...
# 7  RT @Stop2Care: Why aren't more "news" people s...
# 8  Why aren't more "news" people saying that the ...
# 9  RT @TAFEeducation: ‘Two research papers releas...
#
#                        created_at                 time  geo_coordinates  \
# 0  Thu Mar 05 23:51:39 +0000 2020  05/03/2020 23:51:39              NaN
# 1  Thu Mar 05 23:49:19 +0000 2020  05/03/2020 23:49:19              NaN
# 2  Thu Mar 05 23:47:13 +0000 2020  05/03/2020 23:47:13              NaN
# 3  Thu Mar 05 23:19:27 +0000 2020  05/03/2020 23:19:27              NaN
# 4  Thu Mar 05 23:14:28 +0000 2020  05/03/2020 23:14:28              NaN
# 5  Thu Mar 05 23:11:47 +0000 2020  05/03/2020 23:11:47              NaN
# 6  Thu Mar 05 23:09:12 +0000 2020  05/03/2020 23:09:12              NaN
# 7  Thu Mar 05 23:08:52 +0000 2020  05/03/2020 23:08:52              NaN
# 8  Thu Mar 05 23:06:22 +0000 2020  05/03/2020 23:06:22              NaN
# 9  Thu Mar 05 22:56:39 +0000 2020  05/03/2020 22:56:39              NaN
#
#    user_lang  in_reply_to_user_id_str  ...     from_user_id_str  \
# 0        NaN                      NaN  ...  1175516433469595648
# 1        NaN                      NaN  ...            193566462
# 2        NaN               14709326.0  ...   936038790346493952
# 3        NaN                      NaN  ...           4820930547
# 4        NaN                      NaN  ...            620222951
# 5        NaN                      NaN  ...           2655609206
# 6        NaN                      NaN  ...            882641197
# 7        NaN                      NaN  ...            141009810
# 8        NaN                      NaN  ...            100701580
# 9        NaN                      NaN  ...            252420272
#
#    in_reply_to_status_id_str  \
# 0                        NaN
# 1                        NaN
# 2               1.235394e+18
# 3                        NaN
# 4                        NaN
# 5                        NaN
# 6                        NaN
# 7                        NaN
# 8                        NaN
# 9                        NaN
#
#                                               source  \
# 0  <a href="https://mobile.twitter.com" rel="nofo...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="https://mobile.twitter.com" rel="nofo...
# 3  <a href="http://www.twitter.com" rel="nofollow...
# 4  <a href="http://twitter.com/download/android" ...
# 5  <a href="https://mobile.twitter.com" rel="nofo...
# 6  <a href="http://twitter.com/download/android" ...
# 7  <a href="http://discussionexpress.com" rel="no...
# 8  <a href="https://mobile.twitter.com" rel="nofo...
# 9  <a href="http://twitter.com/#!/download/ipad" ...
#
#                                    profile_image_url user_followers_count  \
# 0  http://pbs.twimg.com/profile_images/1213625794...                 51.0
# 1  http://pbs.twimg.com/profile_images/9927964040...               2572.0
# 2  http://pbs.twimg.com/profile_images/1200850612...                 19.0
# 3  http://pbs.twimg.com/profile_images/1178201475...               2026.0
# 4  http://pbs.twimg.com/profile_images/1191861187...                127.0
# 5  http://pbs.twimg.com/profile_images/4899826396...               5979.0
# 6  http://pbs.twimg.com/profile_images/1054953970...                 78.0
# 7  http://pbs.twimg.com/profile_images/9793274298...               3034.0
# 8  http://pbs.twimg.com/profile_images/4938252281...                215.0
# 9  http://pbs.twimg.com/profile_images/3685777612...               2646.0
#
#    user_friends_count                   user_location  \
# 0               403.0  Texas United States of America
# 1               288.0                       BC Canada
# 2               396.0                         Indiana
# 3                 2.0                          Rwanda
# 4               432.0       South Island, New Zealand
# 5              1187.0                             NaN
# 6               167.0                          Global
# 7               830.0                              NJ
# 8               710.0                 Marin County CA
# 9              4982.0                       Australia
#
#                                           status_url  \
# 0  http://twitter.com/LABruce14/statuses/12357146...
# 1  http://twitter.com/impishchimp/statuses/123571...
# 2  http://twitter.com/Euthyphraud/statuses/123571...
# 3  http://twitter.com/TujyeKunywa/statuses/123570...
# 4  http://twitter.com/carycharlesart/statuses/123...
# 5  http://twitter.com/profjmcadam/statuses/123570...
# 6  http://twitter.com/Vfloribert/statuses/1235703...
# 7  http://twitter.com/imagine_garden/statuses/123...
# 8  http://twitter.com/Stop2Care/statuses/12357032...
# 9  http://twitter.com/gdgoz/statuses/123570078419...
#
#                                         entities_str  \
# 0  {"hashtags":[{"text":"ClimateChange","indices"...
# 1  {"hashtags":[{"text":"ClimateChange","indices"...
# 2  {"hashtags":[{"text":"China","indices":[90,96]...
# 3  {"hashtags":[{"text":"SafetyFirst","indices":[...
# 4  {"hashtags":[{"text":"healthcare","indices":[6...
# 5  {"hashtags":[{"text":"disaster","indices":[47,...
# 6  {"hashtags":[{"text":"SafetyFirst","indices":[...
# 7  {"hashtags":[{"text":"healthcare","indices":[6...
# 8  {"hashtags":[{"text":"healthcare","indices":[5...
# 9  {"hashtags":[],"symbols":[],"user_mentions":[{...
#
#                                          filter_text
# 0  ['wonder', '@', 'algor', '@', 'aoc', '@', 'gre...
# 1  ['imagin', 'coupl', 'virus', 'occur', 'dure', ...
# 2  ['@', 'gravelinstitut', '@', 'realdonaldtrump'...
# 3  ['RT', '@', 'vfloribert', ':', 'awar', '#', 's...
# 4  ['RT', '@', 'stop2car', ':', 'whi', "n't", '``...
# 5  ['new', 'pact', 'pave', 'way', 'innov', 'solut...
# 6  ['awar', '#', 'safetyfirst', '#', 'safetyisper...
# 7  ['RT', '@', 'stop2car', ':', 'whi', "n't", '``...
# 8  ['whi', "n't", '``', 'news', "''", 'peopl', 's...
# 9  ['RT', '@', 'tafeeduc', ':', '‘', 'two', 'rese...
#
# [10 rows x 21 columns]
